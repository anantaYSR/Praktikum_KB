# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
x = list(df.iloc[:,5])
y = list(df.iloc[:,2])
plt.bar(x, y, color='red')
plt.title("vertikal")
plt.xlabel("Jenis Iris")
plt.ylabel("Panjang Sepal")
# Out:
# Text(0, 0.5, 'Panjang Sepal')

# %%
plt.figure(figsize= (5,5))
plt.barh(x,y)
plt.title("horizontal")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('Iris.csv')
df.head()
df.isnull().values.any()
SpL = df['SepalLengthCm']
SpW = df['SepalWidthCm']
PtL = df['PetalLengthCm']
PtW = df['PetalWidthCm']
sns.boxplot(x=SpW)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('Iris.csv')
df.head()

fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), center=0, cmap='Blues')
ax.set_title('Korelasi antar atribut pada iris.csv')
# Out:
# Text(0.5, 1.0, 'Korelasi antar atribut pada iris.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('Iris.csv')
df.head()
sns.scatterplot(data = df, x = "Species", y = "SepalLengthCm")
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Iris.csv')
df.head()
plt.plot(df.PetalLengthCm, df.SepalLengthCm)

# %%
df = df.dropna(subset=['SepalWidthCm'])
data_pie = df['SepalWidthCm'].value_counts().rename_axis('SepalWidthCm').reset_index(name='Id_count')
plt.figure(figsize=(10,10))
plt.pie(data_pie.Id_count, labels = data_pie.SepalWidthCm, startangle=90,autopct='%.1f%%')
plt.title('SepalWidthCm')
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(5,5))
sns.countplot(data = df, x='SepalLengthCm', hue='Species')
# Out:
# <AxesSubplot: xlabel='SepalLengthCm', ylabel='count'>

# %%
flight=sns.load_dataset("PetalLengthCm")

may_flight=flight.query("month == 'may' ")
sns.lineplot(data=may_flight.sort_value.tail(5), x="year")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [59], line 1
# ----> 1 flight=sns.load_dataset("PetalLengthCm")
#       3 may_flight=flight.query("month == 'may' ")
#       4 sns.lineplot(data=may_flight.sort_value.tail(5), x="year")
#
# File c:\Users\TUF-GAMING\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:595, in load_dataset(name, cache, data_home, **kws)
#     593 if not os.path.exists(cache_path):
#     594     if name not in get_dataset_names():
# --> 595         raise ValueError(f"'{name}' is not one of the example datasets.")
#     596     urlretrieve(url, cache_path)
#     597 full_path = cache_path
#
# ValueError: 'PetalLengthCm' is not one of the example datasets.
